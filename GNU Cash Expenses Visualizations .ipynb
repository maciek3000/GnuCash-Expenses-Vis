# %%
import piecash
import os
import numpy as np
import pandas as pd
import inspect
from datetime import datetime

# %%
def checkNameForSubCategory(stringList, names=['Maciek', 'Justyna']):
    '''Checks if there is any name from names in List of Strings. 
    List is checked only from the 3rd value up to one before last. 
    
    If the name is found, it is returned. If not, np.nan is returned.
    '''
    returnString = np.nan
    for name in names:
        returnString = name if name in ",".join(stringList[2:-1]) else returnString
    
    return returnString

# %%
#creating a list of lists to be used as a body of DataFrame

pwd_ = %pwd
fileName_ = pwd_ + "\\gnucash_files\\finanse_sql.gnucash"

with piecash.open_book(fileName_) as book:

    transaction_list = []
    for tr in book.transactions:
        split = tr.splits
        for single_row in split:
            if single_row.account.type == "EXPENSE":
                memo = single_row.memo.strip()
                memo = memo if len(memo) > 0 else np.nan

                tempList = list(map(str, [tr.description, 
                                          tr.post_date, 
                                          memo, 
                                          single_row.account.fullname, 
                                          single_row.value, 
                                          tr.currency.mnemonic]))
                transaction_list.append(tempList)

# %%
#creating pandas DataFrame from created list of lists and adding columns

sourceData = transaction_list

financeFrame = pd.DataFrame(sourceData, columns=['Name', 'Date', 'Split Description', 'Account', 'Price', 'Currency'])
financeFrame = financeFrame.sort_values(['Date', 'Name'])
financeFrame['Split Description'] = financeFrame['Split Description'].replace('nan', np.nan)

finalFrame = financeFrame.copy()

#adding Product and Shop from Split Description and Name
finalFrame['Product'] = finalFrame['Split Description'].fillna(finalFrame['Name'])
cond = finalFrame['Split Description'].isnull()
finalFrame['Shop'] = np.where(cond, np.nan, finalFrame['Name'])

finalFrame['ALL_CATEGORIES'] = finalFrame['Account'].apply(lambda x: x.split(":"))

# Extracting info from Account
'''Account -> 'Wydatki:Wspólne:Zakupy:Chemia:Osobiste - Justyna:Artykuły Do Makijażu'
    2nd: Type
    3rd to OneBeforeLast: SubCategory
    Last: Category
    '''
finalFrame['Type'] = finalFrame['ALL_CATEGORIES'].apply(lambda x: x[1])
finalFrame['Category'] = finalFrame['ALL_CATEGORIES'].apply(lambda x: x[-1])
finalFrame['SubCategory'] = finalFrame['ALL_CATEGORIES'].apply(lambda x: ":".join(x[2:-1]).strip() if len(x[2:-1]) >0 else np.nan)
finalFrame['SubType'] = finalFrame['ALL_CATEGORIES'].apply(lambda x: checkNameForSubCategory(x))

# formatting Price and Date
finalFrame['Price'] = finalFrame['Price'].apply(lambda x: float(x))
finalFrame['Date'] = finalFrame['Date'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d"))

# dropping columns that are no longer needed
finalFrame = finalFrame.drop(['Name', 'Split Description', 'Account'], axis = 1)

# %%
finalFrame.head(30)
# Out:
#            Date  Price Currency                    Product  \
# 2033 2019-03-31   6.00      PLN  Pobranie opłaty okresowej
# 80   2019-04-01   5.99      PLN             Pasta do zębów
# 0    2019-04-01   1.00      PLN                    Szatnia
# 82   2019-04-02   2.19      PLN         Makaron Penne 500g
# 83   2019-04-02   1.64      PLN               Jabłka Ligol
# 84   2019-04-02   3.57      PLN                     Banany
# 85   2019-04-02   1.95      PLN     Cisowianka Niegazowana
# 86   2019-04-02   3.89      PLN  Winterfresh Guma Do Żucia
# 87   2019-04-02   2.99      PLN                    Mentosy
# 81   2019-04-02   7.00      PLN                    Kanapka
# 1    2019-04-02   1.00      PLN                    Szatnia
# 88   2019-04-03   1.75      PLN          Eco Baton Crunchy
# 89   2019-04-03   3.35      PLN                 Baton Oreo
# 90   2019-04-04   2.39      PLN           Pasztet Drobiowy
# 91   2019-04-04   2.69      PLN                Chleb Biały
# 92   2019-04-04  17.00      PLN                 Obiad Dnia
# 93   2019-04-04   1.00      PLN        Opakowanie Na Wynos
# 94   2019-04-05  17.50      PLN                Amrit Kebab
# 96   2019-04-05  23.99      PLN                 Octenisept
# 97   2019-04-05   0.79      PLN            Kompresy Jałowe
# 98   2019-04-05   3.00      PLN          Sól Fizjologiczna
# 99   2019-04-05   2.19      PLN         Makaron Penne 500g
# 100  2019-04-05   7.99      PLN         Łosoś Plastry 100g
# 101  2019-04-05   3.99      PLN            Herbata Owocowa
# 102  2019-04-05   4.49      PLN   Szynka z Piersi Kurczaka
# 103  2019-04-05   2.59      PLN                Twaróg 250g
# 104  2019-04-05   2.29      PLN   Ser Twarogowy Chudy 250g
# 105  2019-04-05   5.99      PLN          Masło Ekstra 200g
# 95   2019-04-05   4.95      PLN                  Croissant
# 106  2019-04-05   0.90      PLN                   Kajzerka
#
#                                 Shop  \
# 2033                             NaN
# 80                          Rossmann
# 0                                NaN
# 82                         Biedronka
# 83                         Biedronka
# 84                         Biedronka
# 85                 Carrefour Express
# 86                 Carrefour Express
# 87                 Carrefour Express
# 81                             Rollo
# 1                                NaN
# 88                     Kiosk Inmedio
# 89                     Kiosk Inmedio
# 90                       Freshmarket
# 91                       Freshmarket
# 92               Stołówka Przy Pracy
# 93               Stołówka Przy Pracy
# 94                               NaN
# 96             Apteka Sztuk Pięknych
# 97             Apteka Sztuk Pięknych
# 98             Apteka Sztuk Pięknych
# 99                         Biedronka
# 100                        Biedronka
# 101                        Biedronka
# 102                        Biedronka
# 103                        Biedronka
# 104                        Biedronka
# 105                        Biedronka
# 95    Cukiernia Piekarnia Nowakowski
# 106                  Piekarnia Putka
#
#                                          ALL_CATEGORIES     Type  \
# 2033                  [Wydatki, Maciek, Opłaty Bankowe]   Maciek
# 80    [Wydatki, Wspólne, Zakupy, Chemia, Dom, Łazien...  Wspólne
# 0                              [Wydatki, Wspólne, Inne]  Wspólne
# 82    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 83    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 84    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 85    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 86    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 87    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 81        [Wydatki, Wspólne, Zakupy, Jedzenie Na Wynos]  Wspólne
# 1                              [Wydatki, Wspólne, Inne]  Wspólne
# 88    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 89    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 90    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 91    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 92        [Wydatki, Wspólne, Zakupy, Jedzenie Na Wynos]  Wspólne
# 93        [Wydatki, Wspólne, Zakupy, Jedzenie Na Wynos]  Wspólne
# 94        [Wydatki, Wspólne, Zakupy, Jedzenie Na Wynos]  Wspólne
# 96           [Wydatki, Wspólne, Wydatki medyczne, Leki]  Wspólne
# 97           [Wydatki, Wspólne, Wydatki medyczne, Leki]  Wspólne
# 98           [Wydatki, Wspólne, Wydatki medyczne, Leki]  Wspólne
# 99    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 100   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 101   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 102   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 103   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 104   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 105   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 95    [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
# 106   [Wydatki, Wspólne, Zakupy, Artykuły spożywcze,...  Wspólne
#
#                Category                 SubCategory SubType
# 2033     Opłaty Bankowe                         NaN     NaN
# 80           Jama Ustna  Zakupy:Chemia:Dom:Łazienka     NaN
# 0                  Inne                         NaN     NaN
# 82                Suche   Zakupy:Artykuły spożywcze     NaN
# 83      Owoce i Warzywa   Zakupy:Artykuły spożywcze     NaN
# 84      Owoce i Warzywa   Zakupy:Artykuły spożywcze     NaN
# 85        Soki i Napoje   Zakupy:Artykuły spożywcze     NaN
# 86    Słodycze i Chipsy   Zakupy:Artykuły spożywcze     NaN
# 87    Słodycze i Chipsy   Zakupy:Artykuły spożywcze     NaN
# 81    Jedzenie Na Wynos                      Zakupy     NaN
# 1                  Inne                         NaN     NaN
# 88    Słodycze i Chipsy   Zakupy:Artykuły spożywcze     NaN
# 89    Słodycze i Chipsy   Zakupy:Artykuły spożywcze     NaN
# 90         Mięso i Ryby   Zakupy:Artykuły spożywcze     NaN
# 91             Pieczywo   Zakupy:Artykuły spożywcze     NaN
# 92    Jedzenie Na Wynos                      Zakupy     NaN
# 93    Jedzenie Na Wynos                      Zakupy     NaN
# 94    Jedzenie Na Wynos                      Zakupy     NaN
# 96                 Leki            Wydatki medyczne     NaN
# 97                 Leki            Wydatki medyczne     NaN
# 98                 Leki            Wydatki medyczne     NaN
# 99                Suche   Zakupy:Artykuły spożywcze     NaN
# 100        Mięso i Ryby   Zakupy:Artykuły spożywcze     NaN
# 101      Herbaty i Kawy   Zakupy:Artykuły spożywcze     NaN
# 102        Mięso i Ryby   Zakupy:Artykuły spożywcze     NaN
# 103              Nabiał   Zakupy:Artykuły spożywcze     NaN
# 104              Nabiał   Zakupy:Artykuły spożywcze     NaN
# 105              Nabiał   Zakupy:Artykuły spożywcze     NaN
# 95    Słodycze i Chipsy   Zakupy:Artykuły spożywcze     NaN
# 106            Pieczywo   Zakupy:Artykuły spożywcze     NaN
